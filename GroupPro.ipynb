# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Dataset.csv")
df.head()
# Out:
#    FIPS_code    County State  Lung Cancer  PM2.5  Status Variable  Land_EQI  \
# 0       1001   Autauga    AL         73.9  12.06                1 -0.706591
# 1       1003   Baldwin    AL         68.4  11.12                1 -1.084299
# 2       1005   Barbour    AL         76.1  12.36                1 -1.281470
# 3       1007  Bibb Cou    AL         86.4  12.24                1 -0.827410
# 4       1009  Blount C    AL         73.1  12.97                1 -0.622934
#
#    Sociod_EQI  Built_EQI    LTD  ...  Status   LCI    UCI  Inter   Slp  \
# 0    0.670436  -0.497301   4.79  ...       2  64.3   84.6  42.94  2.60
# 1    0.553073   0.401585   3.68  ...       2  63.9   73.1  40.54  2.76
# 2   -1.236294   0.048854   0.87  ...       2  63.3   90.9  77.48 -0.11
# 3   -0.600018  -1.290857  19.95  ...       2  71.2  104.1  -6.00  7.64
# 4    0.296509  -1.262740  19.95  ...       2  64.5   82.6  37.83  3.36
#
#    control    treat  Local_Treat  AAC      RT
# ...

# %%
df.shape
# Out:
# (2602, 34)

# %%
df.dtypes
# Out:
# FIPS_code            int64
# County              object
# State               object
# Lung Cancer        float64
# PM2.5              float64
# Status Variable      int64
# Land_EQI           float64
# Sociod_EQI         float64
# Built_EQI          float64
# LTD                float64
# Intercept          float64
# Slope              float64
# CLU50_1              int64
# PM10               float64
# SO2                float64
# NO2                float64
# O3                 float64
# CO                 float64
# CN                 float64
# Disel              float64
# CS2                float64
# Air_EQI            float64
# Water_EQI          float64
# EQI                float64
# Status               int64
# LCI                float64
# UCI                float64
# Inter              float64
# Slp                float64
# control            float64
# treat              float64
# Local_Treat        float64
# AAC                  int64
# RT                  object
# ...

# %%
df.isnull().sum()
# Out:
# FIPS_code             0
# County                0
# State                 0
# Lung Cancer           0
# PM2.5                 0
# Status Variable       0
# Land_EQI              0
# Sociod_EQI            0
# Built_EQI             0
# LTD                   0
# Intercept             0
# Slope                 0
# CLU50_1               0
# PM10                  0
# SO2                   0
# NO2                   0
# O3                    0
# CO                    0
# CN                    0
# Disel                 0
# CS2                   0
# Air_EQI               0
# Water_EQI             0
# EQI                   0
# Status                0
# LCI                   0
# UCI                   0
# Inter              2552
# Slp                2552
# control            2552
# treat              2554
# Local_Treat        2554
# AAC                   0
# RT                    0
# dtype: int64

# %%
import seaborn as sns

# %%
cor=sns.scatterplot(x='PM2.5', y='Lung Cancer', data=df)
cor.set_title('PM2.5 and Lung Cancer')
# Out:
# Text(0.5, 1.0, 'PM2.5 and Lung Cancer')

# %%
sns.lmplot(x='PM2.5', y='Lung Cancer', data=df, line_kws={'color':'black'})
